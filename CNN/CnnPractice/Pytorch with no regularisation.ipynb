# %% [markdown]
# **Importing pytorch libraries, Define transformers and load and visualise dataset**

# %%
# Import PyTorch
import torch
import PIL

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
device = 'cuda' #'cpu' if no GPU available
# Out:
# GPU available: True

# %% [markdown]
# **Our Transform data**

# %%
# Transform to a PyTorch tensors and the normalize our valeus between -1 and +1
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.5, ), (0.5, )) ])

# %%
# Load our Training Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=transform)

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 11017713.62it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 200652.69it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:04<00:00, 1076884.79it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 5634727.82it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

# Create a list with our class names
classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
# We have 60,000 Image samples for our training data & 10,000 for our test data
# each 28 x 28 pixels, as they are grayscale, there is no 3rd dimension to our image
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %% [markdown]
# **Visualising our data**

# %%
# Let's view the 50 first images of the MNIST training dataset
import matplotlib.pyplot as plt

figure = plt.figure()
num_of_images = 50

for index in range(1, num_of_images + 1):
    plt.subplot(5, 10, index)
    plt.axis('off')
    plt.imshow(trainset.data[index], cmap='gray_r')

# %%
import matplotlib.pyplot as plt
import numpy as np

# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))

# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))

# %% [markdown]
# # **2. Building and Training Our Simple CNN with No Regularisation**
#
# #### **Defining Our Model**

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# **Defining our loss and optimizatio function**

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # **3. Training Our Model**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)

                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 4.248, Test Accuracy = 51.860%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 2.222, Test Accuracy = 70.150%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.489, Test Accuracy = 73.650%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.361, Test Accuracy = 74.650%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.286, Test Accuracy = 74.270%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.187, Test Accuracy = 74.100%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.217, Test Accuracy = 75.980%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.177, Test Accuracy = 77.380%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.132, Test Accuracy = 78.690%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.115, Test Accuracy = 77.240%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.131, Test Accuracy = 80.150%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.017, Test Accuracy = 80.400%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.054, Test Accuracy = 76.080%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.025, Test Accuracy = 81.370%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 0.975, Test Accuracy = 80.420%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 0.994, Test Accuracy = 80.840%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 1.065, Test Accuracy = 82.610%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 0.928, Test Accuracy = 82.300%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 0.899, Test Accuracy = 81.230%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 0.909, Test Accuracy = 82.640%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 0.946, Test Accuracy = 82.330%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 0.894, Test Accuracy = 83.640%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.825, Test Accuracy = 82.500%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 0.860, Test Accuracy = 83.250%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 0.868, Test Accuracy = 84.270%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 0.835, Test Accuracy = 84.300%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 0.867, Test Accuracy = 85.030%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.810, Test Accuracy = 83.090%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.845, Test Accuracy = 84.730%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.816, Test Accuracy = 83.800%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.843, Test Accuracy = 84.200%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.794, Test Accuracy = 85.010%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.797, Test Accuracy = 84.450%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.775, Test Accuracy = 85.690%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.755, Test Accuracy = 84.060%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.838, Test Accuracy = 84.000%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.727, Test Accuracy = 85.110%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.724, Test Accuracy = 86.120%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.695, Test Accuracy = 85.800%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.762, Test Accuracy = 86.190%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.714, Test Accuracy = 86.090%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.747, Test Accuracy = 84.780%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.731, Test Accuracy = 85.590%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.781, Test Accuracy = 86.550%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.698, Test Accuracy = 86.150%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.686, Test Accuracy = 87.060%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.724, Test Accuracy = 86.840%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.682, Test Accuracy = 86.880%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.727, Test Accuracy = 86.570%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.654, Test Accuracy = 86.130%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.689, Test Accuracy = 86.390%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.737, Test Accuracy = 86.370%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.669, Test Accuracy = 86.030%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.697, Test Accuracy = 87.350%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.704, Test Accuracy = 87.410%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.647, Test Accuracy = 87.360%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.641, Test Accuracy = 86.890%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.679, Test Accuracy = 87.110%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.617, Test Accuracy = 87.090%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.675, Test Accuracy = 86.740%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.659, Test Accuracy = 86.230%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.646, Test Accuracy = 87.290%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.619, Test Accuracy = 87.490%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.649, Test Accuracy = 87.610%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.624, Test Accuracy = 86.800%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.592, Test Accuracy = 87.600%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.620, Test Accuracy = 86.580%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.634, Test Accuracy = 88.240%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.615, Test Accuracy = 87.280%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.636, Test Accuracy = 88.380%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.632, Test Accuracy = 88.130%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.611, Test Accuracy = 88.160%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.613, Test Accuracy = 88.440%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.583, Test Accuracy = 87.070%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.583, Test Accuracy = 88.440%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.597, Test Accuracy = 87.860%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.613, Test Accuracy = 88.540%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.613, Test Accuracy = 88.410%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.604, Test Accuracy = 88.300%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.625, Test Accuracy = 88.310%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.535, Test Accuracy = 88.050%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.587, Test Accuracy = 88.450%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.577, Test Accuracy = 88.810%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.578, Test Accuracy = 88.840%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.559, Test Accuracy = 87.080%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.548, Test Accuracy = 89.150%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.553, Test Accuracy = 88.480%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.595, Test Accuracy = 87.660%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.579, Test Accuracy = 88.290%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.568, Test Accuracy = 88.310%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.557, Test Accuracy = 89.000%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.532, Test Accuracy = 88.180%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.522, Test Accuracy = 89.090%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.571, Test Accuracy = 88.920%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.555, Test Accuracy = 89.160%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.543, Test Accuracy = 89.150%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.527, Test Accuracy = 88.730%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.562, Test Accuracy = 88.750%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.504, Test Accuracy = 88.530%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.600, Test Accuracy = 88.310%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.530, Test Accuracy = 88.090%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.489, Test Accuracy = 89.320%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.529, Test Accuracy = 88.400%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.529, Test Accuracy = 89.180%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.548, Test Accuracy = 88.760%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.535, Test Accuracy = 86.680%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.575, Test Accuracy = 89.010%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.531, Test Accuracy = 89.000%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.505, Test Accuracy = 88.960%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.525, Test Accuracy = 89.750%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.521, Test Accuracy = 89.430%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.550, Test Accuracy = 89.830%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.499, Test Accuracy = 89.160%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.515, Test Accuracy = 88.610%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.529, Test Accuracy = 88.890%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.480, Test Accuracy = 89.390%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.497, Test Accuracy = 89.450%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.522, Test Accuracy = 89.460%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.518, Test Accuracy = 89.550%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.509, Test Accuracy = 89.340%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.534, Test Accuracy = 89.250%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.522, Test Accuracy = 88.610%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.465, Test Accuracy = 88.800%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.492, Test Accuracy = 89.290%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.483, Test Accuracy = 89.390%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.482, Test Accuracy = 89.340%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.480, Test Accuracy = 89.680%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.466, Test Accuracy = 89.850%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.467, Test Accuracy = 89.830%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.478, Test Accuracy = 89.940%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.484, Test Accuracy = 89.930%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.464, Test Accuracy = 89.880%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.516, Test Accuracy = 89.840%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.467, Test Accuracy = 89.810%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.501, Test Accuracy = 89.320%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.442, Test Accuracy = 89.900%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.475, Test Accuracy = 89.910%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.441, Test Accuracy = 90.100%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.469, Test Accuracy = 90.030%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.502, Test Accuracy = 89.700%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.441, Test Accuracy = 90.140%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.481, Test Accuracy = 90.050%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.486, Test Accuracy = 89.880%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.456, Test Accuracy = 89.560%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.411, Test Accuracy = 90.230%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.501, Test Accuracy = 89.510%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.478, Test Accuracy = 90.050%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.431, Test Accuracy = 90.210%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.416, Test Accuracy = 89.940%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.506, Test Accuracy = 90.560%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.457, Test Accuracy = 90.090%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.440, Test Accuracy = 90.060%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.427, Test Accuracy = 90.260%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.477, Test Accuracy = 89.970%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.448, Test Accuracy = 90.080%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.471, Test Accuracy = 90.340%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.418, Test Accuracy = 89.770%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.415, Test Accuracy = 90.350%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.470, Test Accuracy = 90.170%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.428, Test Accuracy = 90.030%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.416, Test Accuracy = 89.930%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.435, Test Accuracy = 89.470%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.395, Test Accuracy = 90.630%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.398, Test Accuracy = 90.430%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.401, Test Accuracy = 90.270%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.407, Test Accuracy = 90.540%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.434, Test Accuracy = 90.560%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.421, Test Accuracy = 90.620%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.448, Test Accuracy = 90.570%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.409, Test Accuracy = 90.430%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.450, Test Accuracy = 90.000%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.415, Test Accuracy = 90.940%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.423, Test Accuracy = 89.930%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.447, Test Accuracy = 90.480%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.419, Test Accuracy = 89.870%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.388, Test Accuracy = 90.540%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.443, Test Accuracy = 90.660%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.426, Test Accuracy = 90.520%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.400, Test Accuracy = 90.730%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.424, Test Accuracy = 89.980%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.387, Test Accuracy = 90.520%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.433, Test Accuracy = 90.510%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.376, Test Accuracy = 90.770%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.401, Test Accuracy = 90.540%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.387, Test Accuracy = 90.450%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.407, Test Accuracy = 90.500%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.395, Test Accuracy = 90.550%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.407, Test Accuracy = 90.390%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.393, Test Accuracy = 90.910%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.432, Test Accuracy = 90.870%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.419, Test Accuracy = 90.860%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.408, Test Accuracy = 90.120%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.410, Test Accuracy = 90.460%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.394, Test Accuracy = 90.790%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.385, Test Accuracy = 89.620%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.382, Test Accuracy = 91.080%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.385, Test Accuracy = 90.950%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.412, Test Accuracy = 90.750%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.386, Test Accuracy = 90.710%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.362, Test Accuracy = 90.750%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.402, Test Accuracy = 91.030%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.377, Test Accuracy = 90.570%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.401, Test Accuracy = 91.000%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.389, Test Accuracy = 90.640%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.363, Test Accuracy = 90.710%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.353, Test Accuracy = 90.880%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.359, Test Accuracy = 90.930%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.345, Test Accuracy = 90.320%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.359, Test Accuracy = 90.800%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.404, Test Accuracy = 90.930%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.402, Test Accuracy = 91.030%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.349, Test Accuracy = 90.620%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.354, Test Accuracy = 90.850%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.394, Test Accuracy = 90.720%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.403, Test Accuracy = 91.030%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.403, Test Accuracy = 91.010%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.360, Test Accuracy = 91.360%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.345, Test Accuracy = 90.920%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.339, Test Accuracy = 91.420%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.366, Test Accuracy = 91.540%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.332, Test Accuracy = 90.540%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.357, Test Accuracy = 91.050%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.351, Test Accuracy = 91.160%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.389, Test Accuracy = 90.530%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.334, Test Accuracy = 91.150%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.384, Test Accuracy = 91.250%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.335, Test Accuracy = 90.730%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.406, Test Accuracy = 90.990%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.352, Test Accuracy = 90.830%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.354, Test Accuracy = 90.400%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.366, Test Accuracy = 91.390%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.339, Test Accuracy = 91.500%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.361, Test Accuracy = 91.160%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.395, Test Accuracy = 91.340%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.316, Test Accuracy = 91.540%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.311, Test Accuracy = 91.300%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.321, Test Accuracy = 91.070%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.327, Test Accuracy = 91.060%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.341, Test Accuracy = 90.730%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.340, Test Accuracy = 91.440%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.336, Test Accuracy = 91.710%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.349, Test Accuracy = 91.270%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.335, Test Accuracy = 91.390%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.328, Test Accuracy = 90.580%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.327, Test Accuracy = 91.380%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.380, Test Accuracy = 90.520%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.345, Test Accuracy = 90.960%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.343, Test Accuracy = 90.740%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.328, Test Accuracy = 91.360%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.354, Test Accuracy = 91.370%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.352, Test Accuracy = 90.850%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.349, Test Accuracy = 90.880%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.309, Test Accuracy = 91.230%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.305, Test Accuracy = 90.650%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.301, Test Accuracy = 91.320%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.344, Test Accuracy = 91.100%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.304, Test Accuracy = 91.140%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.322, Test Accuracy = 91.670%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.327, Test Accuracy = 91.580%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.308, Test Accuracy = 91.120%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.311, Test Accuracy = 91.370%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.310, Test Accuracy = 90.910%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.309, Test Accuracy = 91.340%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.339, Test Accuracy = 91.130%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.336, Test Accuracy = 91.770%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.343, Test Accuracy = 91.490%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.321, Test Accuracy = 91.590%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.323, Test Accuracy = 91.000%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.342, Test Accuracy = 91.340%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.314, Test Accuracy = 91.230%
# Finished Training

# %% [markdown]
# #**Our Model's Accuracy**

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 90.61%

# %% [markdown]
# **Our Training Plots**

# %%
# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %% [markdown]
# **Saving our Model's Weights**

# %%
PATH = './fashion_mnist_cnn_net.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# # **4. Data Augumentation**
#
# To introduce Data Augmentation to our training data we simply create new Transform functions.
#
# **Recall our previous transformation function**
#
# ```transform = transforms.Compose([transforms.ToTensor(),
#                                transforms.Normalize((0.5, ), (0.5, )) ])```
#
# ### **We are going to firstly demonstrate how Data Augmentation Affects Our Images**

# %%
# We import PIL, an Image Processing library to implement random rotations
from torchvision import transforms
import PIL

data_aug_transform = transforms.Compose([
    transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), shear=5),
    transforms.ColorJitter(hue=0.05, saturation=0.05),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15, interpolation=PIL.Image.BILINEAR),
    transforms.Grayscale(num_output_channels=1)
])

# %% [markdown]
# #### **Perform the Data Augmentatin on a Single Image using the function below to Visualize the effects**

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

def showAugmentations(image, augmentations = 6):
    fig = figure()
    for i in range(augmentations):
        a = fig.add_subplot(1,augmentations,i+1)
        img = data_aug_transform(image)
        imshow(img ,cmap='Greys_r')
        axis('off')

# %%
# Load the first Image from our training data as a numpy array
image = trainset.data[0].numpy()

# Convert it to PIL image's format
img_pil = PIL.Image.fromarray(image)

showAugmentations(img_pil, 8)
