# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 742.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.7/871.7 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.88 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/107.7 GB disk)

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model.train(data="/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/dataset.yaml", epochs=10, imgsz=1920, batch=8,name="footballDetection")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 46.4MB/s]
# Ultralytics YOLOv8.2.88 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO("runs/detect/footballDetection/weights/best.pt")

# %%
# Predict on a video file
results = model.predict(source='/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images', save=True)
# Out:
# image 1/146 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-10_jpg.rf.0955a950bbe84886790fd36798248863.jpg: 1088x1920 1 Ball, 21 Players, 3 Referees, 36.1ms
# image 2/146 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-26_jpg.rf.538dc3be8ff16d7fac0bf539698abb77.jpg: 1088x1920 21 Players, 2 Referees, 25.6ms
# image 3/146 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-28_jpg.rf.3a4c1bc5a6b527a7c19c1908a5df73aa.jpg: 1088x1920 1 Ball, 21 Players, 2 Referees, 24.6ms
# image 4/146 /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/Dataset/test/images/08fd33_0_mp4-2_jpg.rf.992311fb905c1e25061f89c7919c713c.jpg: 1088x1920 1 Ball, 23 Players, 3 Referees, 24.6ms
# ...

# %%
results = model.predict(source="/content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos", save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/2 (frame 1/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 1 Ball, 14 Players, 1 Referee, 24.6ms
# video 1/2 (frame 2/1088) /content/drive/MyDrive/ObjectDetection/FootballPlayerDetection/TestVideos/Messi.mp4: 1088x1920 1 Ball, 14 Players, 1 Referee, 24.5ms
# ...
